# %%
# %pylab inline
import bmi.wrapper
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
model = bmi.wrapper.BMIWrapper(engine='subgrid', configfile='/Users/baart_f/models/duifp/Duifp_default.mdu')

# %%
model.initialize()
model.update(-1)
vars = {}
for var in ['s1', 'maxinterception']:
    vars[var] = model.get_var(var)

# %%
plt.imshow(vars['maxinterception'][::10,::10], vmin=0, vmax=0.1)
