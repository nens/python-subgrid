# %%
import python_subgrid.wrapper
import os.path
import osgeo.gdal
import netCDF4
import numpy as np
import matplotlib.pyplot as plt

# %%
mdu = os.path.expanduser('~/Checkouts/models/delfland-model-voor-3di/hhdlipad.mdu')
mdudir = os.path.dirname(mdu)
#!head $mdu
tifffile = os.path.join(mdudir, 'subgrid/ahn_guts_v9.tif')

# %%
tiff = osgeo.gdal.Open(tifffile)

# %%
band = tiff.GetRasterBand(1)

# %%
nodata = band.GetNoDataValue()
d = band.ReadAsArray()
dmasked = np.ma.masked_array(d, d==nodata)
plt.imshow(dmasked, cmap='gist_earth', vmin=-10, vmax=10)

# %%
x0, dxx, dyx, y0, dyx, dyy= tiff.GetGeoTransform()


thin = 10

nx = tiff.RasterXSize
ny = tiff.RasterYSize

dxx*=thin
dyy*=thin
nx/=thin
ny/=thin

x = np.arange(x0, x0+dxx*nx, dxx)
y = np.arange(y0, y0+dyy*ny, dyy)
fig, ax = plt.subplots()
ax.pcolorfast(x,y, dmasked, cmap='gist_earth', vmin=-10, vmax=10)

# %%
rain = np.zeros_like(dmasked[::thin,::thin])


rain[:,np.floor(nx/2):] = 200
rain.mask = np.logical_or(dmasked[::thin,::thin].mask, rain==0)
ax.pcolorfast(x,y, rain, alpha=0.6, cmap='Reds', vmin=0, vmax=200)
fig

# %%
subgrid = python_subgrid.wrapper.SubgridWrapper(mdu=mdu)

subgrid.start()
# Out:
# INFO:python_subgrid.wrapper:Using subgrid fortran library /home/fedor/.local/lib/libsubgrid.so
# INFO:python_subgrid.wrapper:Loading library from path /home/fedor/.local/lib/libsubgrid.so
# INFO:python_subgrid.wrapper:Current version: Deltares, 3Di - subgrid Version 0.1.1.927M, Dec  4 2013, 16:34:42
# INFO:python_subgrid.wrapper:Startup complete.
# INFO:python_subgrid.wrapper:Loading model /home/fedor/Checkouts/models/delfland-model-voor-3di/hhdlipad.mdu in directory /home/fedor/Checkouts/models/delfland-model-voor-3di
# INFO:python_subgrid.wrapper:Start loadModel for '/home/fedor/Checkouts/models/delfland-model-voor-3di/hhdlipad.mdu'.
# WARNING:python_subgrid.wrapper:Ignored 'Teta' in MDU file, please use 'IntegrationMethod' instead.
# INFO:python_subgrid.wrapper:Wrong NumLayers. Ground water calculations switched off.
# INFO:python_subgrid.wrapper:Reading bathmetry file ' subgrid/ahn_guts_v9.tif '...
# DEBUG:python_subgrid.wrapper:          26   26.7803040      dps(0:imax+1, 0:jmax+1)
# INFO:python_subgrid.wrapper:Completed reading bathymetry file.
# INFO:python_subgrid.wrapper:Opened file : polygons/hhdl_v4.pol
# INFO:python_subgrid.wrapper:Start initialization of grid administration.
# DEBUG:python_subgrid.wrapper:          65   38.6104317      ip,jp
# DEBUG:python_subgrid.wrapper:          65  0.270204008      ls(k)
# DEBUG:python_subgrid.wrapper:          65   6.80719987E-02  ls(k)
# DEBUG:python_subgrid.wrapper:          65   1.72799993E-02  ls(k)
# INFO:python_subgrid.wrapper: Internal nodes =     44206
# INFO:python_subgrid.wrapper: Boundary nodes =   0
# DEBUG:python_subgrid.wrapper:          65   4.42089997E-02  nodk,nodm,nodn
# DEBUG:python_subgrid.wrapper:          65   4.42060009E-02  ks(nodall)
# DEBUG:python_subgrid.wrapper:          65   8.84120017E-02  xz,yz
# INFO:python_subgrid.wrapper: Internal 1D nodes =         0
# INFO:python_subgrid.wrapper: Boundary 1D nodes =   0
# DEBUG:python_subgrid.wrapper:          66  0.188434005      line
# DEBUG:python_subgrid.wrapper:          66  0.376868010      lik,lim,lin,kcu
# DEBUG:python_subgrid.wrapper:          66  0.353655994      nru,nrv
# INFO:python_subgrid.wrapper:Initializing boundaries took:   0.3000D-02 seconds.
# DEBUG:python_subgrid.wrapper:          66   9.42170024E-02  flod
# DEBUG:python_subgrid.wrapper:          67   9.42170024E-02  flou
# DEBUG:python_subgrid.wrapper:          67  0.282651007      dpumin
# DEBUG:python_subgrid.wrapper:          67  0.282651007      dpumax
# WARNING:python_subgrid.wrapper:File
# INFO:python_subgrid.wrapper:Grid Admin initialisation took:  0.9500D-01 seconds.
# INFO:python_subgrid.wrapper:Completed initialization of grid administration.
# DEBUG:python_subgrid.wrapper:          67   4.42060009E-02  dmax(1:nodall)
# DEBUG:python_subgrid.wrapper:          67   4.42060009E-02  dmin(1:nodall)
# DEBUG:python_subgrid.wrapper:          67   4.42060009E-02  sumax(1:nodtot)
# DEBUG:python_subgrid.wrapper:          67  0.176824003      dqmin(1:nodtot)
# DEBUG:python_subgrid.wrapper:          68  0.176824003      dqmax(1:nodtot)
# DEBUG:python_subgrid.wrapper:          68  0.176824003      suqmax(1:nodtot)
# DEBUG:python_subgrid.wrapper:          68  0.176824003      ksq(1:nodtot)
# DEBUG:python_subgrid.wrapper:          68  0.132621005      s1(0:nodall)
# DEBUG:python_subgrid.wrapper:          68  0.188436002      as0(linall,1:2)
# DEBUG:python_subgrid.wrapper:          68  0.188436002      as1(linall,1:2)
# DEBUG:python_subgrid.wrapper:          69   9.42170024E-02  cz(linall)
# DEBUG:python_subgrid.wrapper:          69  0.132621005      si(0:nodall)
# DEBUG:python_subgrid.wrapper:          69  0.282653987      u1(0:linall)
# DEBUG:python_subgrid.wrapper:          69   9.42180008E-02  kf(0:linall)
# DEBUG:python_subgrid.wrapper:          69   4.42069992E-02  vol1(0:nodall)
# DEBUG:python_subgrid.wrapper:          69   8.84139985E-02  vol2(0:nodall)
# DEBUG:python_subgrid.wrapper:          69   8.84139985E-02  su(0:nodall)
# DEBUG:python_subgrid.wrapper:          69   4.42060009E-02  qrain(nodtot)
# DEBUG:python_subgrid.wrapper:          69   8.84139985E-02  volErr(0:nodall)
# DEBUG:python_subgrid.wrapper:          69   9.42170024E-02  conv(linall)
# DEBUG:python_subgrid.wrapper:          70  0.176827997      vq1(0:4*nodall)
# INFO:python_subgrid.wrapper:Calculation of bathymetry statistics took:   0.1800D+00 seconds.
# INFO:python_subgrid.wrapper:Setting initial water levels  from WaterLevelFile took:   0.1000D-02 seconds.
# INFO:python_subgrid.wrapper:Initial floodfill from FloodFill file took:   0.0000D+00 seconds.
# INFO:python_subgrid.wrapper:loadModel complete.

# %%
import logging
python_subgrid.wrapper.logger.setLevel(logging.INFO)

# %%
print(nx, ny)
# Now store the variable in the model
ds = netCDF4.Dataset("precipitation.nc", mode="w", diskless=True, persist=False)

ds.createDimension("nx", nx)
ds.createDimension("ny", ny)

var = ds.createVariable("x", datatype="double", dimensions=("nx",))
var[:] = x[:]
var.standard_name = 'projected_x_coordinate'
var.units = 'm'

var = ds.createVariable("y", datatype="double", dimensions=("ny", ))
var[:] = y[:]
var.standard_name = 'projected_y_coordinate'
var.units = 'm'

var = ds.createVariable("rainfall", datatype="double", dimensions=("ny", "nx"), fill_value=rain.fill_value)
var[:,:] = rain.filled(0)
var.standard_name = 'precipitation'
var.coordinates = 'y x'
var.units = 'mm3/s'

s0 = subgrid.get_nd('s1').copy()
# Don't close the dataset before the model has done the timestep
subgrid.subscribe_dataset('precipitation.nc')
subgrid.update(10.0)
# Clears the memory
ds.close()
# Out:
# INFO:python_subgrid.wrapper: found           3
# INFO:python_subgrid.wrapper: foundx           1 y           2
# INFO:python_subgrid.wrapper:Start timestep-update.
# INFO:python_subgrid.wrapper:reduce time:       0.429000
# INFO:python_subgrid.wrapper: noactive=     44206 nogauss=     25672 nocg     18534
# INFO:python_subgrid.wrapper:Initialization of Flow Values took:   0.3100D-01 seconds.
# INFO:python_subgrid.wrapper:finding rain data for input
# INFO:python_subgrid.wrapper:Timestep 1 number of iterations 1 epsmax   0.3553E-14 idthalf 1  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# (532, 503)

# %%
subgrid.get_nd('t1')
# Out:
# array(60.0)

# %%
s1 = subgrid.get_nd('s1').copy()

# %%
np.allclose(s1, s0) # some water should have appeared
# Out:
# False

# %%
qrain = subgrid.get_nd('qrain').copy()
xz = subgrid.get_nd('FlowElem_xcc').copy()
yz = subgrid.get_nd('FlowElem_ycc').copy()

plt.plot(qrain)

# %%
xz.shape, qrain.shape
# Out:
# ((44207,), (44206,))

# %%
plt.scatter(xz[1:], yz[1:], c=qrain, edgecolor='none')
plt.colorbar()
plt.title('Rainfall')
