# %%
import os
import pandas
import python_subgrid
import netCDF4

# %%
ds = netCDF4.Dataset('../../models/1d-democase/subgrid_map.nc')

# %%
u1 = ds.variables['unorm'][0,:] # called u1 in model
ds.variables['time'].shape
# Out:
# (63,)

# %%
print ds.nFlowLink1d, ds.nFlowLink2d, ds.nFlowLink1dBounds, ds.nFlowLink2dBounds
print ds.variables['unorm'].shape
# Out:
# 68 180 2 0
# (63, 250)

# %%
lines = open('../../models/1d-democase/one_d/netwerk.inp').readlines()
rows = [map(int, line.split()) for line in lines]
nodes = pandas.DataFrame(rows[:6], columns=('idx', 'a', 'x','y','b', 'c'))
nodes = nodes.set_index('idx')
branches = pandas.DataFrame(rows[9:], columns=('idx', 'a', 'node0_idx', 'node1_idx', 'b', 'c', 'd'))
branches = branches.set_index('idx')
fig, ax = plt.subplots(figsize=(20,14))
ax.set_aspect('equal')
ax.plot(nodes.x, nodes.y, 'bs', label='netn', alpha=0.3, markersize=5)

for i, row in branches.iterrows():
    node0 = nodes.ix[row['node0_idx']]
    node1 = nodes.ix[row['node1_idx']]
    ax.text(node0['x']+1, node0['y']+2, node0.name)
    ax.text(node1['x']+1, node1['y']+2, node1.name)
    ax.text((node1['x']+node0['x'])/2.0+1, (node0['y']+node1['y'])/2.0+2, row.name, color='red')
    line = matplotlib.lines.Line2D(xdata=[node0['x'], node1['x']], ydata=[node0['y'], node1['y']])
    
    ax.add_line(line)
ax.set_xlim(auto=True)
ax.set_ylim(456000.0-10, 456100.0+10)
# Out:
# (455990.0, 456110.0)

# %%
xn2d, xn1d,_ = np.split(ds.variables['FlowElem_xcc'][:], np.cumsum([getattr(ds,'nFlowElem2d'),getattr(ds,'nFlowElem1d')]))
yn2d, yn1d,_ = np.split(ds.variables['FlowElem_ycc'][:], np.cumsum([getattr(ds,'nFlowElem2d'),getattr(ds,'nFlowElem1d')]))
xl2d, xl1d,_ = np.split(ds.variables['FlowLink_xu'][:], np.cumsum([getattr(ds,'nFlowLink2d'),getattr(ds,'nFlowLink1d')]))
yl2d, yl1d,_ = np.split(ds.variables['FlowLink_yu'][:], np.cumsum([getattr(ds,'nFlowLink2d'),getattr(ds,'nFlowLink1d')]))
u12d, u11d,_ = np.split(u1, np.cumsum([getattr(ds,'nFlowLink2d'),getattr(ds,'nFlowLink1d')]))

ds.close()

# %%
l = ax.plot(xn1d, yn1d, 'go', label='1dn')
l = ax.plot(xn2d, yn2d, 'k.', alpha=0.3)
l = ax.plot(xl1d, yl1d, 'gx', label='1dl')
l = ax.plot(xl2d, yl2d, 'k+', alpha=0.3)
l = ax.quiver(xl1d, yl1d, np.zeros(u11d.shape), u11d, label='u1 1d', alpha=0.3)
l = ax.quiver(xl2d, yl2d, np.zeros(u12d.shape), u12d, label='u1 2d', alpha=0.3)

ax.legend()
fig

# %%
import python_subgrid.wrapper

# %%
subgrid = python_subgrid.wrapper.SubgridWrapper(mdu='../../models/1d-democase/1D-democase.mdu')

# %%
subgrid.start()
# Out:
# INFO:python_subgrid.wrapper:Using subgrid fortran library /home/fedor/.local/lib/libsubgrid.so
# INFO:python_subgrid.wrapper:Loading library from path /home/fedor/.local/lib/libsubgrid.so
# INFO:python_subgrid.wrapper:Current version: Deltares, 3Di - subgrid Version 0.1.1.858, Oct 24 2013, 14:23:15
# INFO:python_subgrid.wrapper:Startup complete.
# INFO:python_subgrid.wrapper:Loading model ../../models/1d-democase/1D-democase.mdu in directory /home/fedor/Checkouts/models/1d-democase
# INFO:python_subgrid.wrapper:Start loadModel for '../../models/1d-democase/1D-democase.mdu'.
# WARNING:python_subgrid.wrapper:Ignored 'Teta' in MDU file, please use 'IntegrationMethod' instead.
# INFO:python_subgrid.wrapper:Wrong NumLayers. Ground water calculations switched off.
# INFO:python_subgrid.wrapper:Reading bathmetry file ' subgrid/zak_drieharing_100x100.tif '...
# DEBUG:python_subgrid.wrapper:           0   4.08039987E-02  dps(0:imax+1, 0:jmax+1)
# INFO:python_subgrid.wrapper:Completed reading bathymetry file.
# INFO:python_subgrid.wrapper:Start initialization of grid administration.
# INFO:python_subgrid.wrapper: Coarse grid parameters: kmax=           1 , dxmin=   10.0000000
# DEBUG:python_subgrid.wrapper:           0   3.99999991E-02  lg(1:imax,1:jmax)
# INFO:python_subgrid.wrapper:lg init on coarsest level took:   0.0000D+00 seconds.
# INFO:python_subgrid.wrapper:guess dams took:   0.1000D-02 seconds.
# INFO:python_subgrid.wrapper:Searching refinement areas for quadtrees generation took:  0.3000D-02 seconds.
# INFO:python_subgrid.wrapper:Making quadtrees took:   0.2000D-02 seconds.
# INFO:python_subgrid.wrapper:Opened file : boundaries/bound.ext
# INFO:python_subgrid.wrapper: Internal 2d nodes =       100
# INFO:python_subgrid.wrapper: Boundary 2d nodes =   0
# DEBUG:python_subgrid.wrapper: make_channel_network: k1dmax=          11 , k1dtot=           7
# INFO:python_subgrid.wrapper:Opened file : boundaries/bound.ext
# INFO:python_subgrid.wrapper:Opened file : boundaries/bound_wl_up.pli
# INFO:python_subgrid.wrapper:waterlevelbnd boundaries/bound_wl_up.pli       1 nr of open bndcells
# INFO:python_subgrid.wrapper:Opened file : boundaries/bound_wl_down.pli
# INFO:python_subgrid.wrapper:waterlevelbnd boundaries/bound_wl_down.pli       1 nr of open bndcells
# INFO:python_subgrid.wrapper: Internal 1d nodes =        67
# INFO:python_subgrid.wrapper: Boundary 1d nodes =   2
# DEBUG:python_subgrid.wrapper:           0   1.35999999E-03  nru,nrv
# INFO:python_subgrid.wrapper:Opened file : boundaries/bound.ext
# INFO:python_subgrid.wrapper:Initializing external forcing 'waterlevelbnd' from file 'boundaries/bound_wl_up.pli'.
# INFO:python_subgrid.wrapper:Opened file : boundaries/bound_wl_up.pli
# INFO:python_subgrid.wrapper:Opened file : boundaries/bound_wl_up_0001.tim
# INFO:python_subgrid.wrapper:Initializing external forcing 'waterlevelbnd' from file 'boundaries/bound_wl_down.pli'.
# INFO:python_subgrid.wrapper:Opened file : boundaries/bound_wl_down.pli
# INFO:python_subgrid.wrapper:Opened file : boundaries/bound_wl_down_0001.tim
# INFO:python_subgrid.wrapper:Initializing boundaries took:   0.4000D-02 seconds.
# INFO:python_subgrid.wrapper:Assignment of flooding thresholds took:   0.3300D-01 seconds.
# INFO:python_subgrid.wrapper:Grid Admin initialisation took:  0.3500D-01 seconds.
# INFO:python_subgrid.wrapper:Completed initialization of grid administration.
# INFO:python_subgrid.wrapper:Calculation of bathymetry statistics took:   0.1000D-01 seconds.
# INFO:python_subgrid.wrapper:Setting initial water levels  from WaterLevelFile took:   0.0000D+00 seconds.
# INFO:python_subgrid.wrapper:Setting initial water levels on 1d links from WaterLevelFile took:   0.0000D+00 seconds.
# INFO:python_subgrid.wrapper:Initial floodfill from FloodFill file took:   0.1000D-02 seconds.
# INFO:python_subgrid.wrapper:loadModel complete.

# %%
import pandas
df = pandas.DataFrame(data=dict(branch=subgrid.get_nd('link_branchid').copy(),
                           chainage=subgrid.get_nd('link_chainage').copy(),
                           idx=subgrid.get_nd('link_idx').copy()))

# %%
u = subgrid.get_nd('u1')

# %%
for i in range(100):
    subgrid.update(10.0)
# Out:
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 2 number of iterations 21 epsmax   0.1160E+01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 3 number of iterations 21 epsmax   0.5389E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 4 number of iterations 21 epsmax   0.5840E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 5 number of iterations 21 epsmax   0.6042E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 6 number of iterations 21 epsmax   0.4228E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 7 number of iterations 21 epsmax   0.3210E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 8 number of iterations 21 epsmax   0.1377E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 9 number of iterations 21 epsmax   0.8543E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 10 number of iterations 21 epsmax   0.7002E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 11 number of iterations 21 epsmax   0.1277E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 12 number of iterations 21 epsmax   0.1600E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 13 number of iterations 21 epsmax   0.1715E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 14 number of iterations 21 epsmax   0.1677E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 15 number of iterations 21 epsmax   0.1531E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 16 number of iterations 21 epsmax   0.1315E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 17 number of iterations 21 epsmax   0.1428E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 18 number of iterations 21 epsmax   0.4544E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 19 number of iterations 21 epsmax   0.5278E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 20 number of iterations 21 epsmax   0.3978E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 21 number of iterations 21 epsmax   0.1769E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 22 number of iterations 21 epsmax   0.1205E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 23 number of iterations 21 epsmax   0.1638E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 24 number of iterations 21 epsmax   0.2348E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 25 number of iterations 21 epsmax   0.2527E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 26 number of iterations 21 epsmax   0.2352E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 27 number of iterations 21 epsmax   0.1968E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 28 number of iterations 21 epsmax   0.2104E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 29 number of iterations 21 epsmax   0.3843E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 30 number of iterations 21 epsmax   0.3826E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 31 number of iterations 21 epsmax   0.2610E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 32 number of iterations 21 epsmax   0.9955E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 33 number of iterations 21 epsmax   0.8911E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 34 number of iterations 21 epsmax   0.1351E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 35 number of iterations 21 epsmax   0.1833E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 36 number of iterations 21 epsmax   0.1948E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 37 number of iterations 21 epsmax   0.1809E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 38 number of iterations 21 epsmax   0.1518E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 39 number of iterations 21 epsmax   0.1292E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 40 number of iterations 21 epsmax   0.2205E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 41 number of iterations 21 epsmax   0.2302E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 42 number of iterations 21 epsmax   0.1855E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 43 number of iterations 21 epsmax   0.1170E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 44 number of iterations 21 epsmax   0.8701E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 45 number of iterations 21 epsmax   0.3114E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 46 number of iterations 21 epsmax   0.5523E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 47 number of iterations 21 epsmax   0.8401E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 48 number of iterations 21 epsmax   0.1086E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 49 number of iterations 21 epsmax   0.1177E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 50 number of iterations 21 epsmax   0.1153E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 51 number of iterations 21 epsmax   0.8687E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 52 number of iterations 21 epsmax   0.5710E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 53 number of iterations 21 epsmax   0.5012E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 54 number of iterations 21 epsmax   0.8066E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 55 number of iterations 21 epsmax   0.1061E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 56 number of iterations 21 epsmax   0.1480E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 57 number of iterations 21 epsmax   0.1994E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 58 number of iterations 21 epsmax   0.1985E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 59 number of iterations 21 epsmax   0.1580E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 60 number of iterations 21 epsmax   0.9645E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 61 number of iterations 21 epsmax   0.7683E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 62 number of iterations 21 epsmax   0.1031E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 63 number of iterations 21 epsmax   0.7436E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 64 number of iterations 21 epsmax   0.8950E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 65 number of iterations 21 epsmax   0.1025E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 66 number of iterations 21 epsmax   0.1052E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 67 number of iterations 21 epsmax   0.1004E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 68 number of iterations 21 epsmax   0.9039E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 69 number of iterations 21 epsmax   0.7698E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 70 number of iterations 21 epsmax   0.7497E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 71 number of iterations 21 epsmax   0.1299E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 72 number of iterations 21 epsmax   0.1481E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 73 number of iterations 21 epsmax   0.1348E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 74 number of iterations 21 epsmax   0.1013E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 75 number of iterations 21 epsmax   0.5910E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 76 number of iterations 21 epsmax   0.4285E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 77 number of iterations 21 epsmax   0.3766E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 78 number of iterations 21 epsmax   0.4042E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 79 number of iterations 21 epsmax   0.5490E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 80 number of iterations 21 epsmax   0.6096E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 81 number of iterations 21 epsmax   0.6061E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 82 number of iterations 21 epsmax   0.5595E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 83 number of iterations 21 epsmax   0.4891E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 84 number of iterations 21 epsmax   0.4109E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 85 number of iterations 21 epsmax   0.3367E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 86 number of iterations 21 epsmax   0.2736E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 87 number of iterations 21 epsmax   0.2299E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 88 number of iterations 21 epsmax   0.2633E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 89 number of iterations 21 epsmax   0.2800E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 90 number of iterations 21 epsmax   0.6586E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 91 number of iterations 21 epsmax   0.1018E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 92 number of iterations 21 epsmax   0.1169E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 93 number of iterations 21 epsmax   0.1120E+00 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 94 number of iterations 21 epsmax   0.9213E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 95 number of iterations 21 epsmax   0.6378E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 96 number of iterations 21 epsmax   0.3328E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 97 number of iterations 21 epsmax   0.1335E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 98 number of iterations 21 epsmax   0.1859E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 99 number of iterations 21 epsmax   0.3331E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 100 number of iterations 21 epsmax   0.4325E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.
# INFO:python_subgrid.wrapper:Start timestep-update.
# DEBUG:python_subgrid.wrapper: Trying to use timestep:    10.000000000000000
# DEBUG:python_subgrid.wrapper:Start initFlowAdmin, flow_init=              0
# INFO:python_subgrid.wrapper:Timestep 101 number of iterations 21 epsmax   0.4786E-01 idthalf 4  np = 1
# INFO:python_subgrid.wrapper:Timestep complete.

# %%
print subgrid.get_nd('t1')
u = subgrid.get_nd('u1').copy()
link_type = subgrid.get_nd('link_type').copy()
# Out:
# 6.3125

# %%
print link_type.shape, u.shape, 'note that u has an extra internal boundary cell'
df['type'] = np.take(link_type, df.idx-1)
df['u'] = np.take(u, df.idx)
# Out:
# (250,) (251,) note that u has an extra internal boundary cell

# %%
df.head()
# Out:
#    branch   chainage  idx  type         u
# 0       1   0.000000  249     4  2.512683
# 1       1   3.157895  181     2  2.590165
# 2       1   6.315789  182     2  2.669320
# 3       1   9.473684  183     2  2.740009
# 4       1  12.631579  184     2  2.684885

# %%
df['xl1d'] = None
df['yl1d'] = None
df['xl1d'][df['type'] != 4] = xl1d
df['yl1d'][df['type'] != 4] = yl1d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a98a88d70de5> in <module>()
#       1 df['xl1d'] = None
#       2 df['yl1d'] = None
# ----> 3 df['xl1d'][df['type'] != 4] = xl1d
#       4 df['yl1d'][df['type'] != 4] = yl1d
#
# NameError: name 'xl1d' is not defined

# %%
df.shape
# Out:
# (70, 7)

# %%
df_selected = df[df['type'] !=4]

plt.quiver(np.array(df_selected['xl1d']), np.array(df_selected['yl1d']), np.zeros(df_selected['u'].shape), np.array(df_selected['u']))

# %%
subgrid.get_nd('nod_idx')
# Out:
# array([249, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192,
#        193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205,
#        206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218,
#        250, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230,
#        231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243,
#        244, 245, 246, 247], dtype=int32)

# %%
u1
