# %%
# !pwd
import netCDF4
# Out:
# /home/fedor/Checkouts/python-subgrid/notebooks

# %%
ds = netCDF4.Dataset('/home/fedor/Checkouts/models/mozambique/subgrid_map.nc')

# %%
ds.variables.keys()
# Out:
# [u'projected_coordinate_system',
#  u'FlowElem_xcc',
#  u'FlowElem_ycc',
#  u'FlowElemContour_x',
#  u'FlowElemContour_y',
#  u'FlowLink',
#  u'FlowLinkType',
#  u'FlowLink_xu',
#  u'FlowLink_yu',
#  u'sumax',
#  u'time',
#  u's1',
#  u'bath',
#  u'su',
#  u'vol',
#  u'dep',
#  u'ucx',
#  u'ucy',
#  u'unorm',
#  u'au1',
#  u'q',
#  u'interception',
#  u'rain']

# %%
xc = ds.variables['FlowElemContour_x'][:]
yc = ds.variables['FlowElemContour_y'][:]

# %%
verts = [np.c_[x,y] for x,y in zip(xc, yc)]

# %%
polys = matplotlib.collections.PolyCollection(verts)

# %%
fig, ax = plt.subplots(figsize=(20,13))
ax.add_collection(polys)
ax.autoscale()
#

# %%
import python_subgrid.wrapper

# %%
subgrid = python_subgrid.wrapper.SubgridWrapper(mdu='/home/fedor/Checkouts/models/mozambique/mozambique.mdu')
subgrid.start()
# Out:
# INFO:python_subgrid.wrapper:Using subgrid fortran library /home/fedor/.local/lib/libsubgrid.so
# INFO:python_subgrid.wrapper:Loading library from path /home/fedor/.local/lib/libsubgrid.so
# INFO:python_subgrid.wrapper:Current version: Deltares, 3Di - subgrid Version 0.1.1.968:976M, Dec 24 2013, 17:32:14
# INFO:python_subgrid.wrapper:Startup complete.
# INFO:python_subgrid.wrapper:Loading model /home/fedor/Checkouts/models/mozambique/mozambique.mdu in directory /home/fedor/Checkouts/models/mozambique
# INFO:python_subgrid.wrapper:Start loadModel for '/home/fedor/Checkouts/models/mozambique/mozambique.mdu'.
# INFO:python_subgrid.wrapper:Wrong NumLayers. Ground water calculations switched off.
# INFO:python_subgrid.wrapper:Reading bathmetry file ' subgrid/mozambique.tif '...
# ERROR:python_subgrid.wrapper:incompatible filesize pixelsize abs(x) != abs(y)
# DEBUG:python_subgrid.wrapper:          48   48.6442223      dps(0:imax+1, 0:jmax+1)
# ...

# %%
dps = subgrid.get_nd('dps')
dx = subgrid.get_nd('dx')

# %%
dps_ma = np.ma.masked_array(dps, mask=dps == dps.min())

# %%
plt.imshow(-dps_ma, cmap='gist_earth', vmax=300, vmin=-300)

# %%
import mayavi.mlab

# %%
python_subgrid.wrapper.DOCUMENTED_VARIABLES
# Out:
# {u'FlowElemContour_x': u'List of x points forming flow element',
#  u'FlowElemContour_y': u'List of y points forming flow element',
#  u'FlowLink': u'Flow links/lines between coarse grid cells: line(L,1) = nod1, line(L,2) = nod2',
#  u'FlowLink_xcc': u'Cell center x coordinate (pressure point) for all quadtree cells (i.e. nodes).',
#  u'FlowLink_xu': u'Velocity x coordinate for 1d, 2d, including boundaries',
#  u'FlowLink_ycc': u'Cell center y coordinate (pressure point) for all quadtree cells (i.e. nodes).',
#  u'FlowLink_yu': u'Velocity y coordinate for 1d, 2d, including boundaries',
#  u'LandUse': u'percentage of a crop per node',
#  u'MaxInterception': u'max thickness of interception layer on fine base grid',
#  u'ade': u'advection',
#  u'adi': u'advection',
#  u'culverts': u'Culvert',
#  u'dps': u'bathymetry pixel values on fine base grid',
#  u'ds1d': u'gridsize in 1d channels',
#  u'dsnop': u'Dummy missing value for bathymetry pixels, single precision.',
#  u'dt': u'delta t',
# ...

# %%
subgrid.get_var_shape('FlowElemContour_x')
# Out:
# (7341, 4)

# %%
xc = subgrid.get_nd('FlowElemContour_x').copy()

yc = subgrid.get_nd('FlowElemContour_y').copy()
s1 = subgrid.get_nd('s1').copy()

# %%
verts = [np.c_[x,y] for x,y in zip(xc, yc)]

# %%
polys = matplotlib.collections.PolyCollection(verts)
fig, ax = plt.subplots(figsize=(20,15))
N = matplotlib.colors.Normalize(0, s1[1:].max())

colors= matplotlib.cm.Accent(N(s1[1:]))
polys.set_facecolors(colors)
ax.add_collection(polys)
ax.autoscale()

# %%
from tvtk.api import  tvtk

# %%
extent = [subgrid.get_nd(x) for x in ('x0p', 'x1p', 'y0p', 'y1p')] + [-20, 20]
#mayavi.mlab.imshow(dps_ma)
thin = 10
D = dps_ma[::thin,::thin].filled(0).copy()
print D.shape
im = mayavi.mlab.imshow(D)
#image_actor1.actor.position = array([ 0.,  0.,  0.])
#image_actor1.actor.scale = array([ 1.,  2.,  1.])
im.actor.position[0] = extent[0]
im.actor.position[1] = extent[2]

# add a 2darray source
#array_source = engine.scenes[0].children[0]
#array_source.spacing = array([ 50.,  50.,   1.])
# add a warp scalar
# add a warp scaler with an extent to the 
# array_source.origin = array([  672897.6024 ,  7803312.85833,   -10000.     ])

#im.actor.scale[0] = (extent[1] - extent[0])/dps_ma.shape[1]
#im.actor.scale[1] = (extent[3] - extent[2])/dps_ma.shape[0]
# Out:
# (671, 726)

# %%
grid = tvtk.UnstructuredGrid()
ncells = xc.shape[0]
X = np.tile(xc, (1,2))
Y = np.tile(yc, (1,2))

Z = np.c_[ np.zeros(xc.shape)- (s1[1:].min() - 1), np.repeat(s1[1:,np.newaxis], 4, axis=1)]

pts = np.c_[X.ravel(), Y.ravel(), Z.ravel() ]
print ncells
# Out:
# 7341

# %%
cell_array = tvtk.CellArray()
cell_types = np.array([tvtk.Hexahedron().cell_type for i in range(ncells)])
cell_idx = np.array([[8] + [i*8 + j for j in range(8)] for i in range(ncells)]).ravel()
cell_offsets = np.array([i*9 for i in range(ncells)])

cell_array.set_cells(ncells, cell_idx)

# %%
grid.points = pts
grid.set_cells(cell_types, cell_offsets, cell_array)
grid.cell_data.scalars = s1[1:].copy()
grid.cell_data.scalars.name = 's1'

# %%
import mayavi.sources.vtk_data_source
source = mayavi.sources.vtk_data_source.VTKDataSource(data=grid)

# %%
engine = mayavi.mlab.get_engine()

outline = mayavi.modules.outline.Outline()
surface = mayavi.modules.surface.Surface()
# more z
surface.actor.actor.scale[2] = 100
surface.update_pipeline()

# %%
engine.add_source(source)
engine.add_module(outline)
engine.add_module(surface)
mayavi.mlab.show()
# Out:
# WARNING:root:DEPRECATED: pyface.wx.clipboard, use pyface.api instead.
