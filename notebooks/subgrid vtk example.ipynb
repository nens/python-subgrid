# %%
# !pwd
import netCDF4
# Out:
# /media/fedor/My Passport/SanFrancisco/models/watersheed

# %%
ds = netCDF4.Dataset('subgrid_map.nc')

# %%
ds.variables.keys()
# Out:
# [u'projected_coordinate_system',
#  u'FlowElem_xcc',
#  u'FlowElem_ycc',
#  u'FlowElemContour_x',
#  u'FlowElemContour_y',
#  u'FlowLink',
#  u'FlowLinkType',
#  u'FlowLink_xu',
#  u'FlowLink_yu',
#  u'sumax',
#  u'time',
#  u's1',
#  u'bath',
#  u'su',
#  u'vol',
#  u'dep',
#  u'ucx',
#  u'ucy',
#  u'unorm',
#  u'au1',
#  u'q',
#  u'interception',
#  u'rain']

# %%
xc = ds.variables['FlowElemContour_x'][:]
yc = ds.variables['FlowElemContour_y'][:]

# %%
verts = [np.c_[x,y] for x,y in zip(xc, yc)]

# %%
polys = matplotlib.collections.PolyCollection(verts)

# %%
fig, ax = plt.subplots(figsize=(20,13))
ax.add_collection(polys)
ax.autoscale()
#

# %%
import python_subgrid.wrapper

# %%
subgrid = python_subgrid.wrapper.SubgridWrapper(mdu='TamalpaisValley.mdu')
subgrid.start()
# Out:
# INFO:python_subgrid.wrapper:Using subgrid fortran library /home/fedor/.local/lib/libsubgrid.so
# INFO:python_subgrid.wrapper:Loading library from path /home/fedor/.local/lib/libsubgrid.so
# INFO:python_subgrid.wrapper:Current version: Deltares, 3Di - subgrid Version 0.1.1.927M, Dec  4 2013, 16:34:42
# INFO:python_subgrid.wrapper:Startup complete.
# INFO:python_subgrid.wrapper:Loading model TamalpaisValley.mdu in directory /media/fedor/My Passport/SanFrancisco/models/watersheed
# INFO:python_subgrid.wrapper:Start loadModel for 'TamalpaisValley.mdu'.
# WARNING:python_subgrid.wrapper:Ignored 'Teta' in MDU file, please use 'IntegrationMethod' instead.
# INFO:python_subgrid.wrapper:Wrong NumLayers. Ground water calculations switched off.
# INFO:python_subgrid.wrapper:Reading bathmetry file ' TamalpaisValley.tiff '...
# DEBUG:python_subgrid.wrapper:           1   1.00048006      dps(0:imax+1, 0:jmax+1)
# INFO:python_subgrid.wrapper:Completed reading bathymetry file.
# INFO:python_subgrid.wrapper:Opened file : dike.pol
# INFO:python_subgrid.wrapper:Start initialization of grid administration.
# INFO:python_subgrid.wrapper: Coarse grid parameters: kmax=           3 , dxmin=   20.0000000
# DEBUG:python_subgrid.wrapper:           1  0.996479988      lg(1:imax,1:jmax)
# INFO:python_subgrid.wrapper:lg init on coarsest level took:   0.2000D-01 seconds.
# INFO:python_subgrid.wrapper:guess dams took:   0.1600D-01 seconds.
# INFO:python_subgrid.wrapper:Searching refinement areas for quadtrees generation took:  0.3800D-01 seconds.
# INFO:python_subgrid.wrapper:Making quadtrees took:   0.1040D+00 seconds.
# INFO:python_subgrid.wrapper: Internal nodes =      5153
# INFO:python_subgrid.wrapper: Boundary nodes =   0
# DEBUG:python_subgrid.wrapper:           2   5.15299989E-03  nodm(nodall)
# DEBUG:python_subgrid.wrapper:           2   5.15299989E-03  nodn(nodall)
# DEBUG:python_subgrid.wrapper:           2   5.15299989E-03  nodk(nodall)
# DEBUG:python_subgrid.wrapper:           2   5.15400013E-03  ks(0:nodall)
# DEBUG:python_subgrid.wrapper:           2   1.03059998E-02  xz(nodall),yz(nodall)
# INFO:python_subgrid.wrapper: Internal 1D nodes =         0
# INFO:python_subgrid.wrapper: Boundary 1D nodes =   0
# DEBUG:python_subgrid.wrapper:           2   4.12320010E-02  nru,nrv
# INFO:python_subgrid.wrapper:Initializing boundaries took:   0.1000D-02 seconds.
# INFO:python_subgrid.wrapper:Assignment of flooding thresholds took:   0.3320D+00 seconds.
# WARNING:python_subgrid.wrapper:File
# INFO:python_subgrid.wrapper:Grid Admin initialisation took:  0.3350D+00 seconds.
# INFO:python_subgrid.wrapper:Completed initialization of grid administration.
# DEBUG:python_subgrid.wrapper:           2   5.15299989E-03  dmax(1:nodall)
# DEBUG:python_subgrid.wrapper:           2   5.15299989E-03  dmin(1:nodall)
# DEBUG:python_subgrid.wrapper:           2   5.15299989E-03  sumax(1:nodtot)
# DEBUG:python_subgrid.wrapper:           2   2.06119996E-02  dqmin(1:nodtot)
# DEBUG:python_subgrid.wrapper:           2   2.06119996E-02  dqmax(1:nodtot)
# DEBUG:python_subgrid.wrapper:           2   2.06119996E-02  suqmax(1:nodtot)
# DEBUG:python_subgrid.wrapper:           2   2.06119996E-02  ksq(1:nodtot)
# DEBUG:python_subgrid.wrapper:           2   1.54619999E-02  s1(0:nodall)
# DEBUG:python_subgrid.wrapper:           2   2.18359996E-02  as0(linall,1:2)
# DEBUG:python_subgrid.wrapper:           2   2.18359996E-02  as1(linall,1:2)
# DEBUG:python_subgrid.wrapper:           2   1.09169995E-02  cz(linall)
# DEBUG:python_subgrid.wrapper:           2   1.54619999E-02  si(0:nodall)
# DEBUG:python_subgrid.wrapper:           2   3.27540003E-02  u1(0:linall)
# DEBUG:python_subgrid.wrapper:           2   1.09179998E-02  kf(0:linall)
# DEBUG:python_subgrid.wrapper:           2   5.15400013E-03  vol1(0:nodall)
# DEBUG:python_subgrid.wrapper:           2   1.03080003E-02  vol2(0:nodall)
# DEBUG:python_subgrid.wrapper:           2   1.03080003E-02  su(0:nodall)
# DEBUG:python_subgrid.wrapper:           2   5.15299989E-03  qrain(nodtot)
# DEBUG:python_subgrid.wrapper:           2   1.03080003E-02  volErr(0:nodall)
# DEBUG:python_subgrid.wrapper:           2   1.09169995E-02  conv(linall)
# DEBUG:python_subgrid.wrapper:           2   2.06160005E-02  vq1(0:4*nodall)
# INFO:python_subgrid.wrapper:Calculation of bathymetry statistics took:   0.1000D-01 seconds.
# INFO:python_subgrid.wrapper:Setting initial water levels  from WaterLevelFile took:   0.0000D+00 seconds.
# INFO:python_subgrid.wrapper:Initial floodfill from FloodFill file took:   0.0000D+00 seconds.
# INFO:python_subgrid.wrapper:loadModel complete.

# %%
dps = subgrid.get_nd('dps')
dx = subgrid.get_nd('dx')

# %%
dps_ma = np.ma.masked_array(dps, mask=dps == dps.min())

# %%
plt.imshow(-dps_ma, cmap='gist_earth', vmax=300, vmin=-300)

# %%
import mayavi.mlab

# %%
xc = subgrid.get_nd('FlowElemContour_x').copy()
yc = subgrid.get_nd('FlowElemContour_y').copy()
s1 = subgrid.get_nd('s1').copy()

# %%
verts = [np.c_[x,y] for x,y in zip(xc.T, yc.T)]

# %%
polys = matplotlib.collections.PolyCollection(verts)
fig, ax = plt.subplots(figsize=(20,15))
ax.add_collection(polys)
ax.autoscale()

# %%
from tvtk.api import  tvtk

# %%
grid = tvtk.UnstructuredGrid()
ncells = xc.shape[1]
X = np.tile(xc.T, (1,2))
Y = np.tile(yc.T, (1,2))
Z = np.c_[ np.zeros(xc.T.shape)- (s1[1:].min() - 1), np.repeat(s1[1:,np.newaxis], 4, axis=1)]

pts = np.c_[X.ravel(), Y.ravel(), Z.ravel() ]
pts[:8]
# Out:
# array([[  5.38970000e+05,   4.19269600e+06,   0.00000000e+00],
#        [  5.39050000e+05,   4.19269600e+06,   0.00000000e+00],
#        [  5.39050000e+05,   4.19277600e+06,   0.00000000e+00],
#        [  5.38970000e+05,   4.19277600e+06,   0.00000000e+00],
#        [  5.38970000e+05,   4.19269600e+06,   2.23694000e+02],
#        [  5.39050000e+05,   4.19269600e+06,   2.23694000e+02],
#        [  5.39050000e+05,   4.19277600e+06,   2.23694000e+02],
#        [  5.38970000e+05,   4.19277600e+06,   2.23694000e+02]])

# %%
cell_array = tvtk.CellArray()
cell_types = np.array([tvtk.Hexahedron().cell_type for i in range(ncells)])
cell_idx = np.array([[8] + [i*8 + j for j in range(8)] for i in range(ncells)]).ravel()
cell_offsets = np.array([i*9 for i in range(ncells)])

cell_array.set_cells(ncells, cell_idx)

# %%
grid.points = pts
grid.set_cells(cell_types, cell_offsets, cell_array)

# %%
import mayavi.sources.vtk_data_source
source = mayavi.sources.vtk_data_source.VTKDataSource(data=grid)

# %%
engine = mayavi.mlab.get_engine()

outline = mayavi.modules.outline.Outline()
surface = mayavi.modules.surface.Surface()

# %%
engine.add_source(source)
engine.add_module(outline)
engine.add_module(surface)
mayavi.mlab.show()
